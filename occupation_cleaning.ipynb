# %%
import pandas as pd
import numpy as np

# %%
occupation = pd.read_csv("/project/data_new/Data_OCCUPATION_AGE_UNIT.csv")

occupation.head()
# Out:
#    CDU_ID   GEO_CODE               GEO_LABEL           GEO_TYPE GEO_TYP2  \
# 0     NaN        NaN                     NaN                NaN      NaN
# 1   374.0  E09000007                  Camden  Local Authorities       LA
# 2   379.0  E09000012                 Hackney  Local Authorities       LA
# 3   380.0  E09000013  Hammersmith and Fulham  Local Authorities       LA
# 4   381.0  E09000014                Haringey  Local Authorities       LA
#
#                                              F349793  \
# 0  Age : Age 16 to 24 - Economic activity : Econo...
# 1                                                494
# 2                                                535
# 3                                                570
# 4                                                446
#
#                                              F349800  \
# 0  Age : Age 16 to 24 - Economic activity : Econo...
# 1                                               1936
# ...

# %%
# change names of columns

# first row new entries for the first four columns
occupation[[0, 0]] = 'CDU_ID'
occupation.head()
# Out:
#    CDU_ID   GEO_CODE               GEO_LABEL           GEO_TYPE GEO_TYP2  \
# 0     NaN        NaN                     NaN                NaN      NaN
# 1   374.0  E09000007                  Camden  Local Authorities       LA
# 2   379.0  E09000012                 Hackney  Local Authorities       LA
# 3   380.0  E09000013  Hammersmith and Fulham  Local Authorities       LA
# 4   381.0  E09000014                Haringey  Local Authorities       LA
#
#                                              F349793  \
# 0  Age : Age 16 to 24 - Economic activity : Econo...
# 1                                                494
# 2                                                535
# 3                                                570
# 4                                                446
#
#                                              F349800  \
# 0  Age : Age 16 to 24 - Economic activity : Econo...
# 1                                               1936
# ...
